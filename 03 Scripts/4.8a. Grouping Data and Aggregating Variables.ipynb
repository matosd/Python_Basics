# %%
# Import libraries
import pandas as pd
import numpy as np
import os

# %%
# Define path
path = r'/Users/d_matos/Desktop/Career Foundry/4. Python Fundamentals for Data Analysts/Instacart Basket Analysis'

# %%
#Import dataframe from 4.7
df48 = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_merged_derived.pkl'))

# %%
df48.shape
# Out:
# (32404859, 18)

# %%
df48.columns
# Out:
# Index(['order_id', 'user_id', 'order_number', 'order_day_of_week',
#        'order_hour_of_day', 'days_since_prior_order', 'product_id',
#        'add_to_cart_order', 'reordered', '_merge', 'product_name', 'aisle_id',
#        'department_id', 'prices', 'price_range_loc', 'busiest_day',
#        'busiest_days', 'busiest_period_of_day'],
#       dtype='object')

# %%
df48 = df48.drop(columns = ['busiest_days', 'busiest_period_of_day'])

# %%
df48.columns
# Out:
# Index(['order_id', 'user_id', 'order_number', 'order_day_of_week',
#        'order_hour_of_day', 'days_since_prior_order', 'product_id',
#        'add_to_cart_order', 'reordered', '_merge', 'product_name', 'aisle_id',
#        'department_id', 'prices', 'price_range_loc', 'busiest_day'],
#       dtype='object')

# %%
df48.shape
# Out:
# (32404859, 16)

# %%
#Create subset
df48b = df48[:1000000]

# %%
df48b.shape
# Out:
# (1000000, 16)

# %%
df48b.head()
# Out:
#    order_id  user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                  2                  8
# 1   2539329        1             1                  2                  8
# 2   2539329        1             1                  2                  8
# 3   2539329        1             1                  2                  8
# 4   2539329        1             1                  2                  8
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered _merge  \
# 0                     7.0         196                  1          0   both
# 1                     7.0       14084                  2          0   both
# 2                     7.0       12427                  3          0   both
# 3                     7.0       26088                  4          0   both
# 4                     7.0       26405                  5          0   both
#
# ...

# %%
df48b.groupby('product_name')

# %%
df48b.groupby('department_id').agg({'order_number': ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 1                14.800024
# 2                17.091743
# 3                17.913544
# 4                17.893092
# 5                15.214270
# 6                15.382135
# 7                17.694027
# 8                16.458105
# 9                15.957363
# 10               20.091818
# 11               16.482026
# 12               15.615061
# 13               16.484023
# 14               17.524632
# 15               15.691875
# 16               18.014071
# 17               16.150593
# 18               19.602850
# 19               17.631340
# 20               17.138607
# 21               21.956893

# %%
df48b.groupby('department_id')['order_number'].mean()
# Out:
# department_id
# 1     14.800024
# 2     17.091743
# 3     17.913544
# 4     17.893092
# 5     15.214270
# 6     15.382135
# 7     17.694027
# 8     16.458105
# 9     15.957363
# 10    20.091818
# 11    16.482026
# 12    15.615061
# 13    16.484023
# 14    17.524632
# 15    15.691875
# 16    18.014071
# 17    16.150593
# 18    19.602850
# 19    17.631340
# 20    17.138607
# 21    21.956893
# Name: order_number, dtype: float64

# %%
df48b.groupby('department_id').order_number.mean()
# Out:
# department_id
# 1     14.800024
# 2     17.091743
# 3     17.913544
# 4     17.893092
# 5     15.214270
# 6     15.382135
# 7     17.694027
# 8     16.458105
# 9     15.957363
# 10    20.091818
# 11    16.482026
# 12    15.615061
# 13    16.484023
# 14    17.524632
# 15    15.691875
# 16    18.014071
# 17    16.150593
# 18    19.602850
# 19    17.631340
# 20    17.138607
# 21    21.956893
# Name: order_number, dtype: float64

# %%
df48b.groupby('department_id').agg({'order_number': ['mean', 'min', 'max']})
# Out:
#               order_number
#                       mean min max
# department_id
# 1                14.800024   1  99
# 2                17.091743   1  98
# 3                17.913544   1  99
# 4                17.893092   1  99
# 5                15.214270   1  99
# 6                15.382135   1  99
# 7                17.694027   1  99
# 8                16.458105   1  91
# 9                15.957363   1  99
# 10               20.091818   1  99
# 11               16.482026   1  99
# 12               15.615061   1  99
# 13               16.484023   1  99
# 14               17.524632   1  99
# 15               15.691875   1  99
# 16               18.014071   1  99
# 17               16.150593   1  99
# 18               19.602850   1  99
# 19               17.631340   1  99
# 20               17.138607   1  99
# 21               21.956893   1  97

# %%
df48['max_order'] = df48.groupby(['user_id'])['order_number'].transform(np.max)
# Out:
# /var/folders/f_/j8ww1w0j12g9crz0bs29_xl80000gn/T/ipykernel_8092/2929553259.py:1: FutureWarning: The provided callable <function max at 0x112d69a80> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   df48['max_order'] = df48.groupby(['user_id'])['order_number'].transform(np.max)

# %%
df48['max_order'] = df48.groupby(['user_id'])['order_number'].transform('max')

# %%
df48.head(100)
# Out:
#     order_id  user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0    2539329        1             1                  2                  8
# 1    2539329        1             1                  2                  8
# 2    2539329        1             1                  2                  8
# 3    2539329        1             1                  2                  8
# 4    2539329        1             1                  2                  8
# ..       ...      ...           ...                ...                ...
# 95    738281        2             4                  2                 10
# 96   1673511        2             5                  3                 11
# 97   1673511        2             5                  3                 11
# 98   1673511        2             5                  3                 11
# 99   1673511        2             5                  3                 11
#
#     days_since_prior_order  product_id  add_to_cart_order  reordered _merge  \
# ...

# %%
pd.options.display.max_rows = None

# %%
df48.loc[df48['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'

# %%
df48.loc[(df48['max_order'] <= 40) & (df48['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'

# %%
df48.loc[df48['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

# %%
df48['loyalty_flag'].value_counts(dropna = False)
# Out:
# loyalty_flag
# Regular customer    15876776
# Loyal customer      10284093
# New customer         6243990
# Name: count, dtype: int64

# %%
df48[['user_id', 'loyalty_flag', 'order_number']].head(60)
# Out:
#     user_id      loyalty_flag  order_number
# 0         1      New customer             1
# 1         1      New customer             1
# 2         1      New customer             1
# 3         1      New customer             1
# 4         1      New customer             1
# 5         1      New customer             2
# 6         1      New customer             2
# 7         1      New customer             2
# 8         1      New customer             2
# 9         1      New customer             2
# 10        1      New customer             2
# 11        1      New customer             3
# 12        1      New customer             3
# 13        1      New customer             3
# 14        1      New customer             3
# 15        1      New customer             3
# 16        1      New customer             4
# 17        1      New customer             4
# 18        1      New customer             4
# 19        1      New customer             4
# ...

# %%
df48.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'orders_products_merged_derived_aggregated.pkl'))
