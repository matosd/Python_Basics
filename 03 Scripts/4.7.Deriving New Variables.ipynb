# %%
# Import libraries
import pandas as pd
import numpy as np
import os

# %%
# Define path
path = r'/Users/d_matos/Desktop/Career Foundry/4. Python Fundamentals for Data Analysts/Instacart Basket Analysis'

# %%
#Import dataframe with all the data combined so far
df47 = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_all.pkl'))

# %%
df47.head()
# Out:
#    order_id  user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                  2                  8
# 1   2539329        1             1                  2                  8
# 2   2539329        1             1                  2                  8
# 3   2539329        1             1                  2                  8
# 4   2539329        1             1                  2                  8
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered _merge  \
# 0                     7.0         196                  1          0   both
# 1                     7.0       14084                  2          0   both
# 2                     7.0       12427                  3          0   both
# 3                     7.0       26088                  4          0   both
# 4                     7.0       26405                  5          0   both
#
#                               product_name  aisle_id  department_id  prices
# ...

# %%
df47.shape
# Out:
# (32404859, 14)

# %%
# Create subset
df47b = df47[:1000000]

# %%
df47b.shape
# Out:
# (1000000, 14)

# %%
# Define a function for prices
def price_label(row):
  if row['prices'] <= 5:
    return 'Low-range product'
  elif (row['prices'] > 5) and (row['prices'] <= 15):
    return 'Mid-range product'
  elif row['prices'] > 15:
    return 'High range'
  else: return 'Not enough data'

# %%
# Apply the function
df47b['price_range'] = df47b.apply(price_label, axis=1)
# Out:
# /var/folders/f_/j8ww1w0j12g9crz0bs29_xl80000gn/T/ipykernel_6283/1944014999.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df47b['price_range'] = df47b.apply(price_label, axis=1)

# %%
df47b['price_range'].value_counts(dropna = False)
# Out:
# price_range
# Mid-range product    673183
# Low-range product    314392
# High range            12425
# Name: count, dtype: int64

# %%
df47b['prices'].max()
# Out:
# 99999.0

# %%
df47b.head()
# Out:
#    order_id  user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                  2                  8
# 1   2539329        1             1                  2                  8
# 2   2539329        1             1                  2                  8
# 3   2539329        1             1                  2                  8
# 4   2539329        1             1                  2                  8
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered _merge  \
# 0                     7.0         196                  1          0   both
# 1                     7.0       14084                  2          0   both
# 2                     7.0       12427                  3          0   both
# 3                     7.0       26088                  4          0   both
# 4                     7.0       26405                  5          0   both
#
# ...

# %%
df47b.loc[df47b['prices'] > 15, 'price_range_loc'] = 'High-range product'
# Out:
# /var/folders/f_/j8ww1w0j12g9crz0bs29_xl80000gn/T/ipykernel_6283/2337921691.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df47b.loc[df47b['prices'] > 15, 'price_range_loc'] = 'High-range product'

# %%
df47b.loc[(df47b['prices'] <= 15) & (df47b['prices'] > 5), 'price_range_loc'] = 'Mid-range product'

# %%
df47b.loc[df47b['prices'] <= 5, 'price_range_loc'] = 'Low-range product'

# %%
df47b['price_range_loc'].value_counts(dropna = False)
# Out:
# price_range_loc
# Mid-range product     673183
# Low-range product     314392
# High-range product     12425
# Name: count, dtype: int64

# %%
df47.loc[df47['prices'] > 15, 'price_range_loc'] = 'High-range product'

# %%
df47.loc[(df47['prices'] <= 15) & (df47['prices'] > 5), 'price_range_loc'] = 'Mid-range product'

# %%
df47.loc[df47['prices'] <= 5, 'price_range_loc'] = 'Low-range product'

# %%
df47['price_range_loc'].value_counts(dropna = False)
# Out:
# price_range_loc
# Mid-range product     21860860
# Low-range product     10126321
# High-range product      417678
# Name: count, dtype: int64

# %%
df47['price_range_loc'].value_counts(dropna = True)
# Out:
# price_range_loc
# Mid-range product     21860860
# Low-range product     10126321
# High-range product      417678
# Name: count, dtype: int64

# %%
#Orders by day of the week
df47['order_day_of_week'].value_counts (dropna = False)
# Out:
# order_day_of_week
# 0    6204182
# 1    5660230
# 6    4496490
# 2    4213830
# 5    4205791
# 3    3840534
# 4    3783802
# Name: count, dtype: int64

# %%
result = []

for value in df47["order_day_of_week"]:
  if value == 0:
    result.append("Busiest day")
  elif value == 4:
    result.append("Least busy")
  else:
    result.append("Regularly busy")

# %%
result
# Out:
# ['Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
# ...

# %%
df47['busiest_day'] = result

# %%
df47['busiest_day'].value_counts (dropna = False)
# Out:
# busiest_day
# Regularly busy    22416875
# Busiest day        6204182
# Least busy         3783802
# Name: count, dtype: int64

# %%
#Identify the two busiest and slowest days
orders_per_day = df47['order_day_of_week'].value_counts(dropna=False).sort_index()

# %%
busiest_days = orders_per_day.nlargest(2).index.tolist()

# %%
slowest_days = orders_per_day.nsmallest(2).index.tolist()

# %%
# Create the new column `busiest_days`
df47['busiest_days'] = 'Regularly busy'

# %%
df47.loc[df47['order_day_of_week'].isin(busiest_days), 'busiest_days'] = 'Busiest days'

# %%
df47.loc[df47['order_day_of_week'].isin(slowest_days), 'busiest_days'] = 'Slowest days'

# %%
print(df47['busiest_days'].value_counts(dropna=False))
# Out:
# busiest_days
# Regularly busy    12916111
# Busiest days      11864412
# Slowest days       7624336
# Name: count, dtype: int64

# %%
# The busiest periods of the day
orders_per_hour = df47['order_hour_of_day'].value_counts()

# %%
most_orders_threshold = orders_per_hour.quantile(0.75)

# %%
fewest_orders_threshold = orders_per_hour.quantile(0.25)

# %%
df47['busiest_period_of_day'] = 'Average orders'

# %%
df47.loc[df47['order_hour_of_day'].isin(orders_per_hour[orders_per_hour >= most_orders_threshold].index), 'busiest_period_of_day'] = 'Most orders'

# %%
df47.loc[df47['order_hour_of_day'].isin(orders_per_hour[orders_per_hour <= fewest_orders_threshold].index), 'busiest_period_of_day'] = 'Fewest orders'

# %%
print(df47['busiest_period_of_day'].value_counts())
# Out:
# busiest_period_of_day
# Most orders       16128666
# Average orders    15679865
# Fewest orders       596328
# Name: count, dtype: int64

# %%
df47.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'orders_products_merged_derived.pkl'))
